# %%
# !pip install stable-baselines3[extra]
# Out:
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.11/dist-packages (2.1.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (0.29.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (3.7.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (4.11.0.86)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (7.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (14.0.0)
# Requirement already satisfied: shimmy~=1.1.0 in /usr/local/lib/python3.11/dist-packages (from shimmy[atari]~=1.1.0; extra == "extra"->stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (11.2.1)
# Requirement already satisfied: autorom~=0.6.1 in /usr/local/lib/python3.11/dist-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.32.4)
# Requirement already satisfied: AutoROM.accept-rom-license in /usr/local/lib/python3.11/dist-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3[extra]) (2.4.1)
# Requirement already satisfied: ale-py~=0.8.1 in /usr/local/lib/python3.11/dist-packages (from shimmy[atari]~=1.1.0; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.73.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.8.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (25.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.8)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3[extra]) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]) (2.19.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.1.0; extra == "extra"->stable-baselines3[extra]) (6.5.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.20->stable-baselines3[extra]) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.20->stable-baselines3[extra]) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.20->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.20->stable-baselines3[extra]) (2024.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (2025.6.15)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.20->stable-baselines3[extra]) (2024.2.0)

# %%
import platform
import torch
import math
import sys
import os
import random
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from abc import ABC
import numpy as np
import random
import tkinter as tk
import tkinter.font as tf
import copy
from itertools import combinations
from tqdm import tqdm

# %%
# Add the path to kaggle_datasets
sys.path.append(kaggle_datasets_path)
print(sys.path)
# Out:
# ['/kaggle/working', '/kaggle/lib/kagglegym', '/kaggle/lib', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '/usr/local/lib/python3.11/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.11/dist-packages/IPython/extensions', '/usr/local/lib/python3.11/dist-packages/setuptools/_vendor', '/root/.ipython', '/kaggle/input/bioinformatics-project-dataset/', '/tmp/tmp311p7e62', '/kaggle/input/bioinformatics-project-dataset/', '/kaggle/input/bioinformatics-project-dataset/', '/kaggle/input/bioinformatics-project-dataset/', '/kaggle/input/bioinformatics-project-dataset/', '/kaggle/input/bioinformatics-project-dataset/', '/kaggle/input/bioinformatics-project-dataset/', '/kaggle/input/bioinformatics-project-dataset/', '/kaggle/input/bioinformatics-project-dataset/']

# %%
import dataset3
import dataset4
import dataset5
import dataset6

# %%
import torch
import torch.nn as nn
import numpy as np
import torch.nn.functional as F

"""
    Referenced from Github: https://github.com/huggingface/transformers
"""


def get_pad_mask(seq, pad_idx):
    return (seq != pad_idx).unsqueeze(-2)


def get_subsequent_mask(seq):
    sz_b, len_s = seq.size()
    subsequent_mask = (1 - torch.triu(
        torch.ones((1, len_s, len_s), device=seq.device), diagonal=1)).bool()
    return subsequent_mask


class ScaledDotProductAttention(nn.Module):
    def __init__(self, temperature, attn_dropout=0.1):
        super().__init__()
        self.temperature = temperature
        self.dropout = nn.Dropout(attn_dropout)

    def forward(self, q, k, v, mask=None):
        attn = torch.matmul(q / self.temperature, k.transpose(2, 3))

        if mask is not None:
            attn = attn.masked_fill(mask == 0, -1e9)

        attn = self.dropout(F.softmax(attn, dim=-1))
        output = torch.matmul(attn, v)

        return output, attn


class PositionalEncoding(nn.Module):

    def __init__(self, d_hid, n_position=200):
        super(PositionalEncoding, self).__init__()

        self.register_buffer('pos_table', self._get_sinusoid_encoding_table(n_position, d_hid))

    def _get_sinusoid_encoding_table(self, n_position, d_hid):
        def get_position_angle_vec(position):
            return [position / np.power(10000, 2 * (hid_j // 2) / d_hid) for hid_j in range(d_hid)]

        sinusoid_table = np.array([get_position_angle_vec(pos_i) for pos_i in range(n_position)])
        sinusoid_table[:, 0::2] = np.sin(sinusoid_table[:, 0::2])
        sinusoid_table[:, 1::2] = np.cos(sinusoid_table[:, 1::2])

        return torch.FloatTensor(sinusoid_table).unsqueeze(0)

    def forward(self, x):
        y = self.pos_table[:, :x.size(1)].clone().detach()
        return x + y


class SelfAttention(nn.Module):
    def __init__(self, d_model, d_k, d_v, dropout=0.1):
        super().__init__()

        self.d_k = d_k
        self.d_v = d_v

        self.w_qs = nn.Linear(d_model, d_k, bias=False)
        self.w_ks = nn.Linear(d_model, d_k, bias=False)
        self.w_vs = nn.Linear(d_model, d_v, bias=False)
        self.fc = nn.Linear(d_v, d_model, bias=False)

        self.attention = ScaledDotProductAttention(temperature=d_k ** 0.5)

        self.dropout = nn.Dropout(dropout)
        self.layer_norm = nn.LayerNorm(d_model, eps=1e-6)

    def forward(self, q, k, v, mask=None):
        d_k, d_v = self.d_k, self.d_v
        sz_b, len_q, len_k, len_v = q.size(0), q.size(1), k.size(1), v.size(1)

        residual = q

        q = self.w_qs(q).view(sz_b, len_q, 1, d_k)
        k = self.w_ks(k).view(sz_b, len_k, 1, d_k)
        v = self.w_vs(v).view(sz_b, len_v, 1, d_v)

        q, k, v = q.transpose(1, 2), k.transpose(1, 2), v.transpose(1, 2)

        if mask is not None:
            mask = mask.unsqueeze(1)

        q, attn = self.attention(q, k, v, mask=mask)

        q = q.transpose(1, 2).contiguous().view(sz_b, len_q, -1)
        q = self.dropout(self.fc(q))
        q += residual

        q = self.layer_norm(q)

        return q, attn


class Encoder(nn.Module):
    def __init__(
            self, n_src_vocab, d_model, n_position, d_k=164, d_v=164,
            pad_idx=0, dropout=0.1):
        super().__init__()
        self.pad_idx = pad_idx
        self.src_word_emb = nn.Embedding(n_src_vocab, d_model, padding_idx=pad_idx)
        self.position_enc = PositionalEncoding(d_model, n_position=n_position)
        self.dropout = nn.Dropout(p=dropout)
        self.layer_norm = nn.LayerNorm(d_model, eps=1e-6)
        self.self_attention = SelfAttention(d_model, d_k, d_v, dropout=dropout)

    def forward(self, src_seq, mask):
        enc_output = self.src_word_emb(src_seq)
        enc_output = self.position_enc(enc_output)
        enc_output = self.dropout(enc_output)
        enc_output = self.layer_norm(enc_output)
        enc_output, enc_slf_attn = self.self_attention(enc_output, enc_output, enc_output, mask=mask)

        return enc_output

# %%
import gymnasium as gym
import numpy as np
from gymnasium import spaces


class DPA_MSA_ENV_SB3(gym.Env):
    
    nucleotides_map = {'A': 1, 'T': 2, 'C': 3, 'G': 4, 'a': 1, 't': 2, 'c': 3, 'g': 4, '-': 5}
    
    def __init__(self, dataset, match_reward = 4, mismatch_penalty = -4, gap_penalty = -4):
        super().__init__()
        self.episodes_dict = {}
        self.step_count = 0
        self.match_reward = match_reward
        self.mismatch_penalty = mismatch_penalty
        self.gap_penalty = gap_penalty
        start = 0
        end = -1
        self.data = []
        self.max_len = 0
        self.total_reward = 0
        nucleotides_map = {'A': 1, 'T': 2, 'C': 3, 'G': 4, 'a': 1, 't': 2, 'c': 3, 'g': 4, '-': 5}
        self.ep_count = 0

        for index, name in enumerate(dataset.datasets[start:end if end != -1 else len(dataset.datasets)], start):
            if not hasattr(dataset, name):
                continue
            seqs = getattr(dataset, name)
            self.max_len = max(max([len(seqs[i]) for i in range(len(seqs))]), self.max_len)
            self.data.append([[nucleotides_map[seqs[i][j]] for j in range(len(seqs[i]))] for i in range(len(seqs))])

        self.row = len(self.data[0])
        self.action_number = 2 ** (self.row) - 2
        self.max_reward = self.row * (self.row - 1) / 2 * self.match_reward
        self.min_reward = self.row * (self.row - 1) / 2 * min(self.mismatch_penalty, self.gap_penalty)
        self.action_space = spaces.Discrete(self.action_number)
        self.reward_range = (self.min_reward, self.max_reward)
        self.observation_space = spaces.Box(low=0, high=5, shape=(self.row * (self.max_len),), dtype=np.uint8)

    def __get_obs(self):
        state = []
        for i in range(self.row):
            state.extend((self.not_aligned[i][j] if j < len(self.not_aligned[i]) else 5) for j in range(len(self.not_aligned[i])))

        state.extend([0 for _ in range(self.row * (self.max_len) - len(state))])
        return np.array(state, dtype=np.uint8)

    def __calc_reward(self):
        score = 0
        tail = len(self.aligned[0]) - 1
        for j in range(self.row):
            for k in range(j + 1, self.row):
                if self.aligned[j][tail] == 5 or self.aligned[k][tail] == 5:
                    score += self.gap_penalty
                elif self.aligned[j][tail] == self.aligned[k][tail]:
                    score += self.match_reward
                elif self.aligned[j][tail] != self.aligned[k][tail]:
                    score += self.mismatch_penalty

        return score

    def calc_col_score_aligned(self):
        score = 0

        for i in range(len(self.aligned[0])):
            n = self.aligned[0][i]
            flag = True
            for j in range(1, self.row):
                if n != self.aligned[j][i]:
                    flag = False
                    break
            if flag:
                score += 1

        return score/len(self.aligned[0])
    
    def step(self, action):
        self.step_count += 1
        for bit in range(self.row):
            if 0 == (action >> bit) & 0x1 and 0 == len(self.not_aligned[bit]):
                self.total_reward += self.min_reward
                self.ep_count += 1
                return self.__get_obs(), self.min_reward, False, True, {}

        total_len = 0
        for bit in range(self.row):
            if 0 == (action >> bit) & 0x1:
                self.aligned[bit].append(self.not_aligned[bit][0])
                self.not_aligned[bit].pop(0)
            else:
                self.aligned[bit].append(5)
            total_len += len(self.not_aligned[bit])
        self.total_reward += self.__calc_reward()
        if total_len > 0:
            return self.__get_obs(), self.__calc_reward(), False, False, {}
        else:
            self.ep_count += 1
            self.episodes_dict[self.ep_count] = {"aligned_val": self.calc_col_score_aligned(), "total_reward": self.total_reward}
            return self.__get_obs(), self.__calc_reward(), True, False, {}

    def reset(self, seed=24, options=None):
        if self.step_count != 0:
            self.total_reward = 0
        self.step_count = 0
        self.done = False
        self.aligned = [[] for _ in range(self.row)]
        row_index = self.np_random.integers(0, len(self.data))
        self.not_aligned = copy.deepcopy(self.data[row_index])
        return self.__get_obs(), {}

# %%
from stable_baselines3.common.env_checker import check_env
env =  DPA_MSA_ENV_SB3(dataset=dataset4, match_reward=4, mismatch_penalty=-4, gap_penalty=-4)
check_env(env)

# %%
from stable_baselines3 import PPO

# %%
import torch
import torch.nn as nn
import numpy as np
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
from stable_baselines3.common.policies import ActorCriticPolicy
from stable_baselines3 import PPO
import gymnasium as gym


class EncoderFeatureExtractor(BaseFeaturesExtractor):
    
    def __init__(self, observation_space: gym.Space, seq_num: int, max_seq_len: int, d_model: int = 64):
        dim = seq_num * (max_seq_len)
        features_dim = dim * d_model
        
        super().__init__(observation_space, features_dim)
        
        self.seq_num = seq_num
        self.max_seq_len = max_seq_len
        self.d_model = d_model
        self.dim = dim
        
        self.encoder = Encoder(6, d_model, dim)
        self.dropout = nn.Dropout()
        
        self.mask = lambda x, y: (x != y).unsqueeze(-2)
        
    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        batch_size = observations.shape[0]
        
        x = observations.view(batch_size, -1).long()
        
        x = self.encoder(x, self.mask(x, 0))
        x = self.dropout(x)
        
        x = x.view(batch_size, -1)

        return x


class CustomNetwork(nn.Module):
    def __init__(self,observation_space, seq_num, max_seq_len, d_model=64, policy_mlp_hidden=[64, 64], value_mlp_hidden=[64, 64]):
        super(CustomNetwork, self).__init__()
        self.features_extractor = EncoderFeatureExtractor(
                observation_space, 
                seq_num, 
                max_seq_len, 
                d_model
            )
            
        features_dim = self.features_extractor.features_dim
            
        policy_layers = []
        prev_dim = features_dim
        for hidden_dim in policy_mlp_hidden[:-1]:
            policy_layers.extend([
                nn.Linear(prev_dim, hidden_dim),
                nn.LeakyReLU()
            ])
            prev_dim = hidden_dim

        policy_layers.extend([nn.Linear(prev_dim, policy_mlp_hidden[-1]), nn.Tanh()])
        self.policy_net = nn.Sequential(*policy_layers)
        
        value_layers = []
        prev_dim = features_dim
        for hidden_dim in value_mlp_hidden[:-1]:
            value_layers.extend([
                nn.Linear(prev_dim, hidden_dim),
                nn.LeakyReLU()
            ])
            prev_dim = hidden_dim

        value_layers.extend([nn.Linear(prev_dim, value_mlp_hidden[-1]), nn.Tanh()])
        self.value_net = nn.Sequential(*value_layers)
        
        self.latent_dim_pi = policy_mlp_hidden[-1] if policy_mlp_hidden else features_dim
        self.latent_dim_vf = value_mlp_hidden[-1] if value_mlp_hidden else features_dim

        
    def forward(self, obs, deterministic: bool = False):
            return self.forward_actor(obs), self.forward_critic(obs)

    def forward_actor(self, obs):
            features = self.features_extractor(obs)
            policy_latent = self.policy_net(features)
            return policy_latent

    def forward_critic(self, obs):
            features = self.features_extractor(obs)
            value_latent = self.value_net(features.detach())
            return value_latent
            
    def extract_features(self, obs):
            return self.features_extractor(obs)
    

class CustomActorCriticPolicy(ActorCriticPolicy):
    def __init__(self, observation_space, action_space, lr_schedule, seq_num, max_seq_len, 
                 d_model=64, policy_mlp_hidden=[64, 64], value_mlp_hidden=[64, 64], **kwargs):
        
        self.seq_num = seq_num
        self.max_seq_len = max_seq_len
        self.d_model = d_model
        self.policy_mlp_hidden = policy_mlp_hidden
        self.value_mlp_hidden = value_mlp_hidden
        self.obs = observation_space
        self.act = action_space
        
        super().__init__(observation_space, action_space, lr_schedule, **kwargs)
        
    def _build_mlp_extractor(self) -> None:
        self.mlp_extractor = CustomNetwork(self.obs, self.seq_num, self.max_seq_len, self.d_model, self.policy_mlp_hidden, self.value_mlp_hidden)

# %%
from stable_baselines3.common.env_util import make_vec_env

# %%
n_envs = 4
msa_vec_env = make_vec_env(lambda: DPA_MSA_ENV_SB3(dataset4) ,n_envs = n_envs)

n_steps = len(msa_vec_env.get_attr('data')[0]) * 10
batch_size = n_steps * n_envs
total_timesteps = batch_size * 1500

seq_num=msa_vec_env.get_attr('row')[0]
max_seq_len=msa_vec_env.get_attr('max_len')[0]
d_model=64

policy_kwargs = {
    'seq_num': seq_num,
    'max_seq_len': max_seq_len,
    'd_model': d_model,
    'policy_mlp_hidden': [1028, 512],
    'value_mlp_hidden': [1028, 512],
}

# %%
model = PPO(
    CustomActorCriticPolicy,
    msa_vec_env,
    batch_size=batch_size, 
    n_steps=n_steps,
    verbose=1,
    policy_kwargs=policy_kwargs
)

model.learn(total_timesteps=total_timesteps)
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 41.2     |
# |    ep_rew_mean     | -807     |
# | time/              |          |
# |    fps             | 1291     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.8         |
# |    ep_rew_mean          | -797         |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0005306326 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | -0.00142     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.3e+04      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 4.75e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 39.8          |
# |    ep_rew_mean          | -771          |
# | time/                   |               |
# |    fps                  | 840           |
# |    iterations           | 3             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 6000          |
# | train/                  |               |
# |    approx_kl            | 0.00027640696 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.64         |
# |    explained_variance   | 1.75e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.47e+04      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000862     |
# |    value_loss           | 4.97e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 38.8          |
# |    ep_rew_mean          | -741          |
# | time/                   |               |
# |    fps                  | 807           |
# |    iterations           | 4             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 8000          |
# | train/                  |               |
# |    approx_kl            | 0.00016093765 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.64         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.42e+04      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000456     |
# |    value_loss           | 4.87e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.5         |
# |    ep_rew_mean          | -735         |
# | time/                   |              |
# |    fps                  | 786          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0002242754 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000458    |
# |    value_loss           | 4.54e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.5         |
# |    ep_rew_mean          | -752         |
# | time/                   |              |
# |    fps                  | 774          |
# |    iterations           | 6            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 0.0002997893 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.36e+04     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00072     |
# |    value_loss           | 4.74e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.8         |
# |    ep_rew_mean          | -733         |
# | time/                   |              |
# |    fps                  | 765          |
# |    iterations           | 7            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 14000        |
# | train/                  |              |
# |    approx_kl            | 0.0002660031 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.63        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.36e+04     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000459    |
# |    value_loss           | 4.75e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 38.1          |
# |    ep_rew_mean          | -715          |
# | time/                   |               |
# |    fps                  | 759           |
# |    iterations           | 8             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 16000         |
# | train/                  |               |
# |    approx_kl            | 0.00019061482 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.62         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.23e+04      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | 0.00027       |
# |    value_loss           | 4.5e+04       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 37.6          |
# |    ep_rew_mean          | -705          |
# | time/                   |               |
# |    fps                  | 756           |
# |    iterations           | 9             |
# |    time_elapsed         | 23            |
# |    total_timesteps      | 18000         |
# | train/                  |               |
# |    approx_kl            | 0.00019512023 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.62         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.25e+04      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | 0.000363      |
# |    value_loss           | 4.53e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 36.6          |
# |    ep_rew_mean          | -675          |
# | time/                   |               |
# |    fps                  | 751           |
# |    iterations           | 10            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 20000         |
# | train/                  |               |
# |    approx_kl            | 0.00016474561 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.61         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.14e+04      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | 0.00146       |
# |    value_loss           | 4.31e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 37            |
# |    ep_rew_mean          | -676          |
# | time/                   |               |
# |    fps                  | 747           |
# |    iterations           | 11            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 22000         |
# | train/                  |               |
# |    approx_kl            | 0.00021385463 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.6          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.06e+04      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | 0.00128       |
# |    value_loss           | 4.14e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 37.2          |
# |    ep_rew_mean          | -675          |
# | time/                   |               |
# |    fps                  | 743           |
# |    iterations           | 12            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 24000         |
# | train/                  |               |
# |    approx_kl            | 0.00032578042 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.6          |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.06e+04      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | 0.00124       |
# |    value_loss           | 4.15e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 36.2          |
# |    ep_rew_mean          | -643          |
# | time/                   |               |
# |    fps                  | 741           |
# |    iterations           | 13            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 26000         |
# | train/                  |               |
# |    approx_kl            | 0.00043009932 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.59         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.99e+04      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | 0.00187       |
# |    value_loss           | 4e+04         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 35            |
# |    ep_rew_mean          | -605          |
# | time/                   |               |
# |    fps                  | 739           |
# |    iterations           | 14            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 28000         |
# | train/                  |               |
# |    approx_kl            | 0.00038811093 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.57         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.87e+04      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | 0.00259       |
# |    value_loss           | 3.77e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 34.8          |
# |    ep_rew_mean          | -596          |
# | time/                   |               |
# |    fps                  | 738           |
# |    iterations           | 15            |
# |    time_elapsed         | 40            |
# |    total_timesteps      | 30000         |
# | train/                  |               |
# |    approx_kl            | 0.00046381558 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.55         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.69e+04      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | 0.00239       |
# |    value_loss           | 3.41e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 34.2         |
# |    ep_rew_mean          | -583         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 16           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 32000        |
# | train/                  |              |
# |    approx_kl            | 0.0005769777 |
# |    clip_fraction        | 5e-05        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.53        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7e+04      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | 0.00327      |
# |    value_loss           | 3.42e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.8         |
# |    ep_rew_mean          | -548         |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 17           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 34000        |
# | train/                  |              |
# |    approx_kl            | 0.0007180745 |
# |    clip_fraction        | 0.00025      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.68e+04     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.00519      |
# |    value_loss           | 3.37e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 33           |
# |    ep_rew_mean          | -534         |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 18           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 36000        |
# | train/                  |              |
# |    approx_kl            | 0.0009387325 |
# |    clip_fraction        | 0.00185      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.54e+04     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.00437      |
# |    value_loss           | 3.09e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 32.6         |
# |    ep_rew_mean          | -506         |
# | time/                   |              |
# |    fps                  | 732          |
# |    iterations           | 19           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 38000        |
# | train/                  |              |
# |    approx_kl            | 0.0011746685 |
# |    clip_fraction        | 0.0064       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.41        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49e+04     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.00519      |
# |    value_loss           | 3.01e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.3         |
# |    ep_rew_mean          | -462         |
# | time/                   |              |
# |    fps                  | 732          |
# |    iterations           | 20           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 40000        |
# | train/                  |              |
# |    approx_kl            | 0.0014663282 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.35        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.00668      |
# |    value_loss           | 2.65e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.7         |
# |    ep_rew_mean          | -405         |
# | time/                   |              |
# |    fps                  | 731          |
# |    iterations           | 21           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 42000        |
# | train/                  |              |
# |    approx_kl            | 0.0017613481 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.21e+04     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.00715      |
# |    value_loss           | 2.45e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.6         |
# |    ep_rew_mean          | -363         |
# | time/                   |              |
# |    fps                  | 730          |
# |    iterations           | 22           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 44000        |
# | train/                  |              |
# |    approx_kl            | 0.0023925211 |
# |    clip_fraction        | 0.0503       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.1         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.09e+03     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.00874      |
# |    value_loss           | 1.84e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.9        |
# |    ep_rew_mean          | -277        |
# | time/                   |             |
# |    fps                  | 729         |
# |    iterations           | 23          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 46000       |
# | train/                  |             |
# |    approx_kl            | 0.006015092 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.42e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.0102      |
# |    value_loss           | 1.5e+04     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26          |
# |    ep_rew_mean          | -178        |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 24          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 48000       |
# | train/                  |             |
# |    approx_kl            | 0.010734049 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.08e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0106      |
# |    value_loss           | 1.03e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.1         |
# |    ep_rew_mean          | -118         |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 25           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 50000        |
# | train/                  |              |
# |    approx_kl            | 0.0063859713 |
# |    clip_fraction        | 0.0742       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.799       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.14e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.0138       |
# |    value_loss           | 6.37e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.4          |
# |    ep_rew_mean          | -90           |
# | time/                   |               |
# |    fps                  | 727           |
# |    iterations           | 26            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 52000         |
# | train/                  |               |
# |    approx_kl            | 0.00080187386 |
# |    clip_fraction        | 0.0301        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.41         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.35e+03      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | 0.0104        |
# |    value_loss           | 4.76e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.8          |
# |    ep_rew_mean          | -81.6         |
# | time/                   |               |
# |    fps                  | 726           |
# |    iterations           | 27            |
# |    time_elapsed         | 74            |
# |    total_timesteps      | 54000         |
# | train/                  |               |
# |    approx_kl            | 0.00066127366 |
# |    clip_fraction        | 0.0184        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.211        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.03e+03      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 0.0101        |
# |    value_loss           | 4.12e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | -65.6        |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 28           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 56000        |
# | train/                  |              |
# |    approx_kl            | 0.0016643433 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.113       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.09e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.00316      |
# |    value_loss           | 4.24e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.6         |
# |    ep_rew_mean          | -59.9        |
# | time/                   |              |
# |    fps                  | 725          |
# |    iterations           | 29           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 58000        |
# | train/                  |              |
# |    approx_kl            | 0.0010467359 |
# |    clip_fraction        | 0.0063       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0732      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.84e+03     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.00662      |
# |    value_loss           | 3.73e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.9        |
# |    ep_rew_mean          | -69.7       |
# | time/                   |             |
# |    fps                  | 724         |
# |    iterations           | 30          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 60000       |
# | train/                  |             |
# |    approx_kl            | 0.000691793 |
# |    clip_fraction        | 0.00295     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0505     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00149     |
# |    value_loss           | 3.69e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.4          |
# |    ep_rew_mean          | -68.5         |
# | time/                   |               |
# |    fps                  | 724           |
# |    iterations           | 31            |
# |    time_elapsed         | 85            |
# |    total_timesteps      | 62000         |
# | train/                  |               |
# |    approx_kl            | 0.00092924276 |
# |    clip_fraction        | 0.0015        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0408       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.74e+03      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -6.62e-05     |
# |    value_loss           | 3.53e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25.4          |
# |    ep_rew_mean          | -83.8         |
# | time/                   |               |
# |    fps                  | 723           |
# |    iterations           | 32            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 64000         |
# | train/                  |               |
# |    approx_kl            | 0.00036528203 |
# |    clip_fraction        | 0.001         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0376       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.95e+03      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | 0.00123       |
# |    value_loss           | 3.96e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.6          |
# |    ep_rew_mean          | -85.8         |
# | time/                   |               |
# |    fps                  | 723           |
# |    iterations           | 33            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 66000         |
# | train/                  |               |
# |    approx_kl            | 0.00030926708 |
# |    clip_fraction        | 0.0005        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0348       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.86e+03      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | 0.00154       |
# |    value_loss           | 3.77e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.1         |
# |    ep_rew_mean          | -55.4        |
# | time/                   |              |
# |    fps                  | 722          |
# |    iterations           | 34           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 68000        |
# | train/                  |              |
# |    approx_kl            | 0.0010886233 |
# |    clip_fraction        | 0.0015       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0319      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.81e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.00153      |
# |    value_loss           | 3.68e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.6          |
# |    ep_rew_mean          | -64.5         |
# | time/                   |               |
# |    fps                  | 722           |
# |    iterations           | 35            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 70000         |
# | train/                  |               |
# |    approx_kl            | 0.00020578844 |
# |    clip_fraction        | 0.0005        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.03         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.65e+03      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 6.79e-05      |
# |    value_loss           | 3.34e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.7          |
# |    ep_rew_mean          | -65.2         |
# | time/                   |               |
# |    fps                  | 722           |
# |    iterations           | 36            |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 72000         |
# | train/                  |               |
# |    approx_kl            | 0.00054348866 |
# |    clip_fraction        | 0.001         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.028        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.68e+03      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | 0.00194       |
# |    value_loss           | 3.41e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.9         |
# |    ep_rew_mean          | -82          |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 37           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 74000        |
# | train/                  |              |
# |    approx_kl            | 0.0010992236 |
# |    clip_fraction        | 0.0015       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0262      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.81e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.00198      |
# |    value_loss           | 3.68e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.8         |
# |    ep_rew_mean          | -63.7        |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 38           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 76000        |
# | train/                  |              |
# |    approx_kl            | 0.0006482341 |
# |    clip_fraction        | 0.001        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0239      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.93e+03     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.00126      |
# |    value_loss           | 3.91e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.2         |
# |    ep_rew_mean          | -62.9        |
# | time/                   |              |
# |    fps                  | 721          |
# |    iterations           | 39           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 78000        |
# | train/                  |              |
# |    approx_kl            | 0.0011982813 |
# |    clip_fraction        | 0.001        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0216      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.5e+03      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.000908     |
# |    value_loss           | 3.04e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.8          |
# |    ep_rew_mean          | -53.6         |
# | time/                   |               |
# |    fps                  | 720           |
# |    iterations           | 40            |
# |    time_elapsed         | 110           |
# |    total_timesteps      | 80000         |
# | train/                  |               |
# |    approx_kl            | 1.0644794e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0204       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.76e+03      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | 7.97e-05      |
# |    value_loss           | 3.56e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.1         |
# |    ep_rew_mean          | -72.2        |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 41           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 82000        |
# | train/                  |              |
# |    approx_kl            | 9.924472e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0195      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79e+03     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 7.38e-05     |
# |    value_loss           | 3.64e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.8         |
# |    ep_rew_mean          | -83.8        |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 42           |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 84000        |
# | train/                  |              |
# |    approx_kl            | 0.0005601365 |
# |    clip_fraction        | 0.0005       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0195      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.93e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -3.07e-05    |
# |    value_loss           | 3.9e+03      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.4          |
# |    ep_rew_mean          | -68.2         |
# | time/                   |               |
# |    fps                  | 720           |
# |    iterations           | 43            |
# |    time_elapsed         | 119           |
# |    total_timesteps      | 86000         |
# | train/                  |               |
# |    approx_kl            | 1.0379554e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0193       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.72e+03      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | 8.31e-05      |
# |    value_loss           | 3.5e+03       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.9         |
# |    ep_rew_mean          | -62.2        |
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 44           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 88000        |
# | train/                  |              |
# |    approx_kl            | 0.0005349127 |
# |    clip_fraction        | 0.001        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0191      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.68e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.000262     |
# |    value_loss           | 3.41e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.5        |
# |    ep_rew_mean          | -41         |
# | time/                   |             |
# |    fps                  | 719         |
# |    iterations           | 45          |
# |    time_elapsed         | 125         |
# |    total_timesteps      | 90000       |
# | train/                  |             |
# |    approx_kl            | 9.54479e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0187     |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.9e+03     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 9.91e-05    |
# |    value_loss           | 3.84e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.3          |
# |    ep_rew_mean          | -61.2         |
# | time/                   |               |
# |    fps                  | 719           |
# |    iterations           | 46            |
# |    time_elapsed         | 127           |
# |    total_timesteps      | 92000         |
# | train/                  |               |
# |    approx_kl            | 9.2014676e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0185       |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.6e+03       |
# |    n_updates            | 450           |
# |    policy_gradient_loss | 9.14e-05      |
# |    value_loss           | 3.25e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.4         |
# |    ep_rew_mean          | -77.2        |
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 47           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 94000        |
# | train/                  |              |
# |    approx_kl            | 9.080768e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0185      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65e+03     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 7.6e-05      |
# |    value_loss           | 3.36e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.3          |
# |    ep_rew_mean          | -65.9         |
# | time/                   |               |
# |    fps                  | 719           |
# |    iterations           | 48            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 96000         |
# | train/                  |               |
# |    approx_kl            | 0.00084876537 |
# |    clip_fraction        | 0.0015        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0179       |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.75e+03      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 0.00337       |
# |    value_loss           | 3.55e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.4         |
# |    ep_rew_mean          | -53.1        |
# | time/                   |              |
# |    fps                  | 719          |
# |    iterations           | 49           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 98000        |
# | train/                  |              |
# |    approx_kl            | 0.0002723513 |
# |    clip_fraction        | 0.0005       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.016       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79e+03     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 5.33e-05     |
# |    value_loss           | 3.62e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 25            |
# |    ep_rew_mean          | -50.2         |
# | time/                   |               |
# |    fps                  | 718           |
# |    iterations           | 50            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 100000        |
# | train/                  |               |
# |    approx_kl            | 0.00026260442 |
# |    clip_fraction        | 0.0005        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0153       |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.74e+03      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | 7.04e-05      |
# |    value_loss           | 3.53e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.4         |
# |    ep_rew_mean          | -59.4        |
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 51           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 102000       |
# | train/                  |              |
# |    approx_kl            | 0.0004991598 |
# |    clip_fraction        | 0.0005       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.015       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+03     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.00018      |
# |    value_loss           | 3.3e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.4         |
# |    ep_rew_mean          | -50.3        |
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 52           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 104000       |
# | train/                  |              |
# |    approx_kl            | 5.444289e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0145      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74e+03     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 6.67e-05     |
# |    value_loss           | 3.53e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.4         |
# |    ep_rew_mean          | -57.4        |
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 53           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 106000       |
# | train/                  |              |
# |    approx_kl            | 5.517602e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0145      |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.74e+03     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 7.28e-05     |
# |    value_loss           | 3.51e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.3         |
# |    ep_rew_mean          | -89.8        |
# | time/                   |              |
# |    fps                  | 718          |
# |    iterations           | 54           |
# ...
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25.2      |
# |    ep_rew_mean          | -64.7     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1482      |
# |    time_elapsed         | 4117      |
# |    total_timesteps      | 2964000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.25e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.12      |
# |    n_updates            | 14810     |
# |    policy_gradient_loss | -1.04e-08 |
# |    value_loss           | 4.2       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.5      |
# |    ep_rew_mean          | -65.9     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1483      |
# |    time_elapsed         | 4120      |
# |    total_timesteps      | 2966000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.4e-07  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.37      |
# |    n_updates            | 14820     |
# |    policy_gradient_loss | -3.45e-08 |
# |    value_loss           | 4.18      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.5      |
# |    ep_rew_mean          | -47.5     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1484      |
# |    time_elapsed         | 4123      |
# |    total_timesteps      | 2968000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.44e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.86      |
# |    n_updates            | 14830     |
# |    policy_gradient_loss | -3.53e-08 |
# |    value_loss           | 4.06      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.7      |
# |    ep_rew_mean          | -69       |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1485      |
# |    time_elapsed         | 4125      |
# |    total_timesteps      | 2970000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.38e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.06      |
# |    n_updates            | 14840     |
# |    policy_gradient_loss | -3.97e-08 |
# |    value_loss           | 4.3       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 26        |
# |    ep_rew_mean          | -78.3     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1486      |
# |    time_elapsed         | 4128      |
# |    total_timesteps      | 2972000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.38e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.04      |
# |    n_updates            | 14850     |
# |    policy_gradient_loss | -2.91e-09 |
# |    value_loss           | 4.09      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25        |
# |    ep_rew_mean          | -67.4     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1487      |
# |    time_elapsed         | 4131      |
# |    total_timesteps      | 2974000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.25e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.92      |
# |    n_updates            | 14860     |
# |    policy_gradient_loss | -2.55e-08 |
# |    value_loss           | 3.91      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25.2      |
# |    ep_rew_mean          | -65.2     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1488      |
# |    time_elapsed         | 4134      |
# |    total_timesteps      | 2976000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.36e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.89      |
# |    n_updates            | 14870     |
# |    policy_gradient_loss | -2.38e-08 |
# |    value_loss           | 4.13      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.7      |
# |    ep_rew_mean          | -41.8     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1489      |
# |    time_elapsed         | 4136      |
# |    total_timesteps      | 2978000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.18e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.8       |
# |    n_updates            | 14880     |
# |    policy_gradient_loss | -4.59e-08 |
# |    value_loss           | 4.05      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.5      |
# |    ep_rew_mean          | -50.3     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1490      |
# |    time_elapsed         | 4139      |
# |    total_timesteps      | 2980000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.34e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.09      |
# |    n_updates            | 14890     |
# |    policy_gradient_loss | -2.1e-08  |
# |    value_loss           | 4.22      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.9      |
# |    ep_rew_mean          | -54.6     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1491      |
# |    time_elapsed         | 4142      |
# |    total_timesteps      | 2982000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.4e-07  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.98      |
# |    n_updates            | 14900     |
# |    policy_gradient_loss | -7.01e-09 |
# |    value_loss           | 4.12      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25.1      |
# |    ep_rew_mean          | -60.3     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1492      |
# |    time_elapsed         | 4145      |
# |    total_timesteps      | 2984000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.25e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.88      |
# |    n_updates            | 14910     |
# |    policy_gradient_loss | -1.33e-08 |
# |    value_loss           | 3.97      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.9      |
# |    ep_rew_mean          | -24.4     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1493      |
# |    time_elapsed         | 4148      |
# |    total_timesteps      | 2986000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.34e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.94      |
# |    n_updates            | 14920     |
# |    policy_gradient_loss | -5.23e-08 |
# |    value_loss           | 4.01      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25.1      |
# |    ep_rew_mean          | -44.4     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1494      |
# |    time_elapsed         | 4150      |
# |    total_timesteps      | 2988000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.42e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.04      |
# |    n_updates            | 14930     |
# |    policy_gradient_loss | -4.01e-08 |
# |    value_loss           | 4.35      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.3      |
# |    ep_rew_mean          | -60.7     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1495      |
# |    time_elapsed         | 4153      |
# |    total_timesteps      | 2990000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.37e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.88      |
# |    n_updates            | 14940     |
# |    policy_gradient_loss | 4.84e-09  |
# |    value_loss           | 4.28      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.4      |
# |    ep_rew_mean          | -55.8     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1496      |
# |    time_elapsed         | 4156      |
# |    total_timesteps      | 2992000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.39e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.92      |
# |    n_updates            | 14950     |
# |    policy_gradient_loss | 1.03e-09  |
# |    value_loss           | 4.06      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25.1      |
# |    ep_rew_mean          | -36.3     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1497      |
# |    time_elapsed         | 4159      |
# |    total_timesteps      | 2994000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.16e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.05      |
# |    n_updates            | 14960     |
# |    policy_gradient_loss | -3.75e-08 |
# |    value_loss           | 4.16      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.8      |
# |    ep_rew_mean          | -71.1     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1498      |
# |    time_elapsed         | 4162      |
# |    total_timesteps      | 2996000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.25e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.9       |
# |    n_updates            | 14970     |
# |    policy_gradient_loss | -9.2e-09  |
# |    value_loss           | 4.09      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.3      |
# |    ep_rew_mean          | -65.4     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1499      |
# |    time_elapsed         | 4164      |
# |    total_timesteps      | 2998000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.2e-07  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2         |
# |    n_updates            | 14980     |
# |    policy_gradient_loss | -2.69e-08 |
# |    value_loss           | 3.93      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 24.7      |
# |    ep_rew_mean          | -58.3     |
# | time/                   |           |
# |    fps                  | 719       |
# |    iterations           | 1500      |
# |    time_elapsed         | 4167      |
# |    total_timesteps      | 3000000   |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.34e-07 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.93      |
# |    n_updates            | 14990     |
# |    policy_gradient_loss | -1.34e-09 |
# |    value_loss           | 4.12      |
# ---------------------------------------

# %%
print(msa_vec_env.get_attr('episodes_dict')[0])
print(msa_vec_env.get_attr('episodes_dict')[1])
print(msa_vec_env.get_attr('episodes_dict')[2])
print(msa_vec_env.get_attr('episodes_dict')[3])
# Out:
# {}
# {}
# {348: {'aligned_val': 0.16666666666666666, 'total_reward': -40}, 350: {'aligned_val': 0.19047619047619047, 'total_reward': 16}, 403: {'aligned_val': 0.19047619047619047, 'total_reward': 24}}
# {111: {'aligned_val': 0.0, 'total_reward': -952}, 416: {'aligned_val': 0.20833333333333334, 'total_reward': -32}}

# %%
import matplotlib.pyplot as plt

episodes_dicts = msa_vec_env.get_attr('episodes_dict')

fig, axes = plt.subplots(n_envs, 2, figsize=(15, 4*n_envs))
if n_envs == 1:
    axes = axes.reshape(1, -1)

for env_idx, episodes_dict in enumerate(episodes_dicts):
    if len(episodes_dict) == 0:
        continue
    axes[env_idx, 0].set_ylim(-500, 200)
    axes[env_idx, 1].set_ylim(0, 1)
    episodes = list(episodes_dict.keys())
    total_rewards = [episodes_dict[ep]["total_reward"] for ep in episodes]
    aligned_vals = [episodes_dict[ep]["aligned_val"] for ep in episodes]
    
    axes[env_idx, 0].plot(episodes, total_rewards, 'b-', marker='o', markersize=1, linewidth=0.2, alpha=0.8)
    axes[env_idx, 0].set_title(f'Environment {env_idx} - SP Score')
    axes[env_idx, 0].set_xlabel('Episode')
    axes[env_idx, 0].set_ylabel('SP Score')
    axes[env_idx, 0].grid(True)
    
    axes[env_idx, 1].plot(episodes, aligned_vals, 'r-', marker='o', markersize=1, linewidth=0.2, alpha=0.8)
    axes[env_idx, 1].set_title(f'Environment {env_idx} - Colmn Score')
    axes[env_idx, 1].set_xlabel('Episode')
    axes[env_idx, 1].set_ylabel('Column Score')
    axes[env_idx, 1].grid(True)

plt.tight_layout()
plt.show()

# %%
class DPA_MSA_ENV_SB3_eval(gym.Env):
    nucleotides_map = {'A': 1, 'T': 2, 'C': 3, 'G': 4, 'a': 1, 't': 2, 'c': 3, 'g': 4, '-': 5}
    
    def __init__(self, data, max_len, match_reward = 4, mismatch_penalty = -4, gap_penalty = -4):
        super().__init__()
        self.episodes_dict = {}
        self.step_count = 0
        self.match_reward = match_reward
        self.mismatch_penalty = mismatch_penalty
        self.gap_penalty = gap_penalty
        self.data = []
        self.max_len = 0
        self.total_reward = 0
        nucleotides_map = {'A': 1, 'T': 2, 'C': 3, 'G': 4, 'a': 1, 't': 2, 'c': 3, 'g': 4, '-': 5}
        self.ep_count = 0
        self.max_len = max_len
        self.data = [[nucleotides_map[data[i][j]] for j in range(len(data[i]))] for i in range(len(data))]
        self.not_aligned = copy.deepcopy(self.data)
        self.row = len(self.data)
        self.action_number = 2 ** (self.row) - 2
        self.max_reward = self.row * (self.row - 1) / 2 * self.match_reward
        self.min_reward = self.row * (self.row - 1) / 2 * min(self.mismatch_penalty, self.gap_penalty)
        self.action_space = spaces.Discrete(self.action_number)
        self.reward_range = (self.min_reward, self.max_reward)
        self.observation_space = spaces.Box(low=0, high=5, shape=(self.row * (self.max_len),), dtype=np.uint8)

    def __get_obs(self):
        state = []
        for i in range(self.row):
            state.extend((
                self.not_aligned[i][j] if j < len(
                    self.not_aligned[i]) else 5) 
                    for j in range(len(self.not_aligned[i])))

        state.extend([0 for _ in range(self.row * (self.max_len) - len(state))])
        return np.array(state, dtype=np.uint8)

    def __calc_reward(self):
        score = 0
        tail = len(self.aligned[0]) - 1
        for j in range(self.row):
            for k in range(j + 1, self.row):
                if self.aligned[j][tail] == 5 or self.aligned[k][tail] == 5:
                    score += self.gap_penalty
                elif self.aligned[j][tail] == self.aligned[k][tail]:
                    score += self.match_reward
                elif self.aligned[j][tail] != self.aligned[k][tail]:
                    score += self.mismatch_penalty

        return score

    def calc_col_score_aligned(self):
        score = 0

        for i in range(len(self.aligned[0])):
            n = self.aligned[0][i]
            flag = True
            for j in range(1, self.row):
                if n != self.aligned[j][i]:
                    flag = False
                    break
            if flag:
                score += 1

        return score/len(self.aligned[0])
    
    def step(self, action):
        self.step_count += 1
        for bit in range(self.row):
            if 0 == (action >> bit) & 0x1 and 0 == len(self.not_aligned[bit]):
                self.total_reward += self.min_reward
                self.ep_count += 1
                return self.__get_obs(), self.min_reward, False, True, {}

        total_len = 0
        for bit in range(self.row):
            if 0 == (action >> bit) & 0x1:
                self.aligned[bit].append(self.not_aligned[bit][0])
                self.not_aligned[bit].pop(0)
            else:
                self.aligned[bit].append(5)
            total_len += len(self.not_aligned[bit])
        self.total_reward += self.__calc_reward()
        if total_len > 0:
            return self.__get_obs(), self.__calc_reward(), False, False, {}
        else:
            self.ep_count += 1
            self.episodes_dict[self.ep_count] = {"aligned_val": self.calc_col_score_aligned(), "total_reward": self.total_reward}
            return self.__get_obs(), self.__calc_reward(), True, False, {}

    def reset(self, seed=24, options=None):
        if self.step_count != 0:
            self.total_reward = 0
        self.step_count = 0
        self.done = False
        self.aligned = [[] for _ in range(self.row)]
        self.not_aligned = copy.deepcopy(self.data)
        return self.__get_obs(), {}

# %%
sp_scores = []
column_scores = []
from stable_baselines3.common.evaluation import evaluate_policy
dataset = dataset4
eval_count = 1000
sample_debt = 0
for index, name in enumerate(dataset.datasets[0:len(dataset.datasets)]):
    seqs = getattr(dataset, name)
    for i in range(eval_count):
        env = DPA_MSA_ENV_SB3_eval(data=seqs, max_len = model.env.get_attr('max_len')[0], match_reward=4, mismatch_penalty=-4, gap_penalty=-4)
        evaluate_policy(model, env, n_eval_episodes=1)
        if len(env.episodes_dict) == 0:
            sample_debt += 1
            break
        
        sample_debt -= 1
        sp_scores.append(env.episodes_dict[1]["total_reward"])
        column_scores.append(env.episodes_dict[1]["aligned_val"])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sp_q1, sp_median, sp_q3 = np.percentile(sp_scores, [25, 50, 75])
col_q1, col_median, col_q3 = np.percentile(column_scores, [25, 50, 75])

sp_bars = ax1.bar(['SP Scores'], [sp_median], 
                  yerr=[[sp_median - sp_q1], [sp_q3 - sp_median]], 
                  capsize=10, 
                  alpha=0.7, 
                  color='blue',
                  edgecolor='black')

ax1.set_ylabel('SP Score')
ax1.set_title('Dataset 1 - SP Scores')
ax1.grid(True, alpha=0.3)

col_bars = ax2.bar(['Column Scores'], [col_median], 
                   yerr=[[col_median - col_q1], [col_q3 - col_median]], 
                   capsize=10, 
                   alpha=0.7, 
                   color='red',
                   edgecolor='black')

ax2.set_ylabel('Column Score')
ax2.set_title('Dataset 1 - Column Scores')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_36/1243746958.py in <cell line: 0>()
#       1 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
# ----> 2 sp_q1, sp_median, sp_q3 = np.percentile(sp_scores, [25, 50, 75])
#       3 col_q1, col_median, col_q3 = np.percentile(column_scores, [25, 50, 75])
#       4
#       5 sp_bars = ax1.bar(['SP Scores'], [sp_median],
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4281     if not _quantile_is_valid(q):
#    4282         raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4283     return _quantile_unchecked(
#    4284         a, q, axis, out, overwrite_input, method, keepdims)
#    4285
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4553                         keepdims=False):
#    4554     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 4555     return _ureduce(a,
#    4556                     func=_quantile_ureduce_func,
#    4557                     q=q,
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/function_base.py in _ureduce(a, func, keepdims, **kwargs)
#    3821                 kwargs['out'] = out[(Ellipsis, ) + index_out]
#    3822
# -> 3823     r = func(a, **kwargs)
#    3824
#    3825     if out is not None:
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/function_base.py in _quantile_ureduce_func(a, q, axis, out, overwrite_input, method)
#    4720         else:
#    4721             arr = a.copy()
# -> 4722     result = _quantile(arr,
#    4723                        quantiles=q,
#    4724                        axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/function_base.py in _quantile(arr, quantiles, axis, method, out)
#    4829             axis=0)
#    4830         if supports_nans:
# -> 4831             slices_having_nans = np.isnan(arr[-1, ...])
#    4832         else:
#    4833             slices_having_nans = None
#
# IndexError: index -1 is out of bounds for axis 0 with size 0
